# %%
import os
import random
import numpy as np
import pandas as pd
import librosa
import librosa.display
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection
from sklearn import preprocessing
import IPython.display as ipd
from pylab import figure, axes, pie, title, show
from matplotlib.backends.backend_agg import FigureCanvasAgg as FigureCanvas
import pylab

# %%
cd C:\Users\Charles\Desktop\AI Cough Detection\Cough
# Out:
# C:\users\charles\desktop\AI Cough Detection\cough

# %%
# Class Distribution
df_data = pd.read_csv('cough2_drive.csv')
g = sns.countplot(df_data['label'])
df_data['label'].value_counts()
# Out:
# 1    140
# Name: label, dtype: int64

# %%
# define directories
base_dir = "./"
esc_dir = os.path.join(base_dir, "cough")
meta_file = os.path.join(base_dir, "cough2_drive.csv")
audio_dir = os.path.join(base_dir, "cough2_drrive/")

# %%
# load metadata
meta_data = pd.read_csv(meta_file)
meta_data
# Out:
#                                               filename  label
# 0                        108017__erocshadow__cough.wav      1
# 1                   132601__carlossolano019__cough.wav      1
# 2                         13799__pfly__babycough01.wav      1
# 3                    142603__loisgwenllian__cough2.wav      1
# 4                    142604__loisgwenllian__cough1.wav      1
# 5             144254__dwoboyle__human-man-coughing.wav      1
# 6    145359__kleanthism__kleaudio-coughdouble-msst.wav      1
# 7                      145487__bmoreno__0005-cough.wav      1
# 8                146873__tgfcoder__male-sick-cough.wav      1
# 9     148212__espaitecnologic__tos-aeiraval-petits.wav      1
# 10                            148224__skxr__cough2.wav      1
# 11                        148310__elgeorgia__cough.wav      1
# 12                    149042__zabuhailo__mancough2.wav      1
# 13                    149043__zabuhailo__mancough1.wav      1
# 14                       151217__owlstorm__cough-3.wav      1
# 15                  152367__cogitoandcradle__cough.wav      1
# 16                           152995__nmb910__cough.wav      1
# 17                         154434__ecfike__cough-1.wav      1
# 18                155603__themightymoltar__choking.wav      1
# 19               155650__poorenglishjuggler__cough.wav      1
# 20                 157296__husky70__coughing-cough.wav      1
# 21         16580__jascha__husten-tief-mit-nachhall.wav      1
# 22                   169217__sitzbrau__04-coughing.wav      1
# 23                          169726__qubodup__cough.wav      1
# 24                        170960__timgormly__cough.wav      1
# 25                         171396__unfa__wet-cough.wav      1
# 26                              17167__lg__cough01.wav      1
# 27                  178997__bigtexan7213__coughing.wav      1
# 28                     18448__zippi1__sound-cough1.wav      1
# 29                         184871__eelke__coughing.wav      1
# ..                                                 ...    ...
# 110                    440692__topschool__coughing.wav      1
# 111                   444064__soulbaby71__coughing.wav      1
# 112           444723__breviceps__short-cough-choke.wav      1
# 113                  445664__tilano408__31-cough-2.wav      1
# 114    445730__180241virtualwindow-co-za__coughing.wav      1
# 115                         446491__obooth3__cough.wav      1
# 116    45150__delphidebrain__delphis-cough-1644-h4.wav      1
# 117                  45578__j-zazvurek__girl-cough.wav      1
# 118                      457972__fabrizio84__cough.wav      1
# 119  458822__lidem-soundfx__fx-toux-stereo-48khz-u8...      1
# 120                 461571__15hkvasnickovat__cough.wav      1
# 121  462010__15f-panska-vokulic-vaclav__coughing-hu...      1
# 122                        462843__eelke__coughing.wav      1
# 123                    466555__danieldouch__coughs.wav      1
# 124         466874__jmbland94__adult-male-coughing.wav      1
# 125           470120__the-coolguy78__child-coffing.wav      1
# 126     51136__rutgermuller__coughing-young-man-me.wav      1
# 127                 52323__stephsinger22__coughing.wav      1
# 128                        53663__crispy527__cough.wav      1
# 129                         58792__syna-max__cough.wav      1
# 130                           62291__shopp__asthma.wav      1
# 131            63752__dobroide__20081118-bad-cough.wav      1
# 132        82717__ifartinurgeneraldirection__cough.wav      1
# 133                85292__smokeyvw__file0281-cough.wav      1
# 134               87411__bowlingballout__man-cough.wav      1
# 135             87412__bowlingballout__woman-cough.wav      1
# 136                         90727__carlcass__cough.wav      1
# 137                        90__plagasul__bocanada2.wav      1
# 138    93031__higginsdj__wheezy-cough-24-96-stereo.wav      1
# 139        96189__ifartinurgeneraldirection__cough.wav      1
#
# [140 rows x 2 columns]

# %%
# load a wave data
def load_wave_data(audio_dir, file_name):
    file_path = os.path.join(audio_dir, file_name)
    x, fs = librosa.load(file_path, sr=44100)
    return x,fs

# %%
# change wave data to mel-stft
def calculate_melsp(x, n_fft=1024, hop_length=128):
    stft = np.abs(librosa.stft(x, n_fft=n_fft, hop_length=hop_length))**2
    log_stft = librosa.power_to_db(stft)
    melsp = librosa.feature.melspectrogram(S=log_stft,n_mels=128)
    return melsp

# %%
# display wave in plots
def show_wave(x):
    plt.plot(x)
    plt.show()

# %%
#display wave in heatmap
def show_melsp(melsp, fs):
    librosa.display.specshow(melsp, sr=fs)
    #plt.colorbar()
    plt.show()
    #plt.axis('off')

# %%
# data augmentation: add white noise
def add_white_noise(x, rate=0.002):
    return x + rate*np.random.randn(len(x))

# %%
# data augmentation: shift sound in timeframe
def shift_sound(x, rate=2):
    return np.roll(x, int(len(x)//rate))

# %%
# data augmentation: stretch sound
def stretch_sound(x, rate=1.1):
    input_length = len(x)
    x = librosa.effects.time_stretch(x, rate)
    if len(x)>input_length:
        return x[:input_length]
    else:
        return np.pad(x, (0, max(0, input_length - len(x))), "constant")

# %%
# !git init
# !git add .
# !git commit -m "Initial commit"
# !git remote add origin https://github.com/CharlesNJohn/Cough.git
# !git push -f origin master
# Out:
# Reinitialized existing Git repository in C:/Users/Charles/Desktop/AI Cough Detection/cough/.git/
# warning: LF will be replaced by CRLF in Cough-Copy1.ipynb.
# The file will have its original line endings in your working directory
# warning: LF will be replaced by CRLF in Cough.ipynb.
# The file will have its original line endings in your working directory
# [master 9015ea5] Initial commit
#  278 files changed, 218 insertions(+), 676 deletions(-)
#  delete mode 100644 cough2_drive/142603__loisgwenllian__cough2.mp3
#  delete mode 100644 cough2_drive/142604__loisgwenllian__cough1.mp3
#  delete mode 100644 cough2_drive/148212__espaitecnologic__tos-aeiraval-petits.mp3
#  delete mode 100644 cough2_drive/148224__skxr__cough2.flac
#  delete mode 100644 cough2_drive/169726__qubodup__cough.flac
#  delete mode 100644 cough2_drive/170960__timgormly__cough.aiff
#  delete mode 100644 cough2_drive/171396__unfa__wet-cough.flac
#  delete mode 100644 cough2_drive/19112__fratz__cough10.aiff
#  delete mode 100644 cough2_drive/207681__blymannen__cough.mp3
#  delete mode 100644 cough2_drive/211197__squeakyballoon__real-flu-chest-cold-coughing-male-middle-aged.mp3
#  delete mode 100644 cough2_drive/240375__mariiao2__cough.mp3
#  delete mode 100644 cough2_drive/254467__wjoojoo__marvie-cough1.flac
#  delete mode 100644 cough2_drive/256567__sjnewton__coughing.mp3
#  delete mode 100644 cough2_drive/259512__fattirewhitey__short-cough.mp3
#  delete mode 100644 cough2_drive/30830__jollysea__girl-coughing.mp3
#  delete mode 100644 cough2_drive/323532__alivvie__wheezy-coughing.mp3
#  delete mode 100644 cough2_drive/325569__activeobjectx__coughs.aiff
#  delete mode 100644 cough2_drive/334051__littlerainyseasons__cough.mp3
#  delete mode 100644 cough2_drive/334154__oddmonolithsound__cough.mp3
#  delete mode 100644 cough2_drive/341086__cabled-mess__unprocessed-cough-rode-nt2000.flac
#  delete mode 100644 cough2_drive/353669__reyhanaf__realistic-cough (1).mp3
#  delete mode 100644 cough2_drive/353669__reyhanaf__realistic-cough.mp3
#  delete mode 100644 cough2_drive/360460__topschool__coughing.mp3
#  delete mode 100644 cough2_drive/360890__dinkdonkdork__young-male-coughing.ogg
#  delete mode 100644 cough2_drive/365476__caitlin-100__a-person-coughing.mp3
#  delete mode 100644 cough2_drive/390317__pflanigan__120716-ack.mp3
#  delete mode 100644 cough2_drive/395199__bvaudio__child-cough.mp3
#  delete mode 100644 cough2_drive/399627__soundsforhim__man-coughing-1.mp3
#  delete mode 100644 cough2_drive/407839__bobtheross__coughing.flac
#  delete mode 100644 cough2_drive/426271__clurky__cough-female.m4a
#  delete mode 100644 cough2_drive/432193__pringlescan__voice-017.m4a
#  delete mode 100644 cough2_drive/440692__topschool__coughing.mp3
#  delete mode 100644 cough2_drive/45578__j-zazvurek__girl-cough.mp3
#  delete mode 100644 cough2_drive/470120__the-coolguy78__child-coffing.m4a
#  delete mode 100644 cough2_drive/85292__smokeyvw__file0281-cough.mp3
#  rename {cough2_drive => cough2_drrive}/108017__erocshadow__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/132601__carlossolano019__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/13799__pfly__babycough01.wav (100%)
#  create mode 100644 cough2_drrive/142603__loisgwenllian__cough2.wav
#  create mode 100644 cough2_drrive/142604__loisgwenllian__cough1.wav
#  rename {cough2_drive => cough2_drrive}/144254__dwoboyle__human-man-coughing.wav (100%)
#  rename {cough2_drive => cough2_drrive}/145359__kleanthism__kleaudio-coughdouble-msst.wav (100%)
#  rename {cough2_drive => cough2_drrive}/145487__bmoreno__0005-cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/146873__tgfcoder__male-sick-cough.wav (100%)
#  create mode 100644 cough2_drrive/148212__espaitecnologic__tos-aeiraval-petits.wav
#  create mode 100644 cough2_drrive/148224__skxr__cough2.wav
#  rename cough2_drive/148310__elgeorgia__cough_MONO.wav => cough2_drrive/148310__elgeorgia__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/149042__zabuhailo__mancough2.wav (100%)
#  rename {cough2_drive => cough2_drrive}/149043__zabuhailo__mancough1.wav (100%)
#  rename {cough2_drive => cough2_drrive}/151217__owlstorm__cough-3.wav (100%)
#  rename {cough2_drive => cough2_drrive}/152367__cogitoandcradle__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/152995__nmb910__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/154434__ecfike__cough-1.wav (100%)
#  rename {cough2_drive => cough2_drrive}/155603__themightymoltar__choking.wav (100%)
#  rename {cough2_drive => cough2_drrive}/155650__poorenglishjuggler__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/157296__husky70__coughing-cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/16580__jascha__husten-tief-mit-nachhall.wav (100%)
#  rename {cough2_drive => cough2_drrive}/169217__sitzbrau__04-coughing.wav (100%)
#  create mode 100644 cough2_drrive/169726__qubodup__cough.wav
#  create mode 100644 cough2_drrive/170960__timgormly__cough.wav
#  create mode 100644 cough2_drrive/171396__unfa__wet-cough.wav
#  rename {cough2_drive => cough2_drrive}/17167__lg__cough01.wav (100%)
#  rename {cough2_drive => cough2_drrive}/178997__bigtexan7213__coughing.wav (100%)
#  rename {cough2_drive => cough2_drrive}/18448__zippi1__sound-cough1.wav (100%)
#  rename {cough2_drive => cough2_drrive}/184871__eelke__coughing.wav (100%)
#  rename {cough2_drive => cough2_drrive}/187909__mark646__husten-femail.wav (100%)
#  rename {cough2_drive => cough2_drrive}/189786__dnewtonjr__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/19023__danglada__cough.wav (100%)
#  create mode 100644 cough2_drrive/19112__fratz__cough10.wav
#  rename {cough2_drive => cough2_drrive}/201262__chrisbrowne626__cough-attack-sound-bit.wav (100%)
#  rename {cough2_drive => cough2_drrive}/201733__univ-lyon3__galle-florian-2013-2014-son3.wav (100%)
#  rename {cough2_drive => cough2_drrive}/204604__pikachu09__cough.wav (100%)
#  create mode 100644 cough2_drrive/207681__blymannen__cough.wav
#  create mode 100644 cough2_drrive/211197__squeakyballoon__real-flu-chest-cold-coughing-male-middle-aged.wav
#  rename {cough2_drive => cough2_drrive}/21314__zippi1__sound-cough2.wav (100%)
#  rename {cough2_drive => cough2_drrive}/218946__annabloom__man-coughing.wav (100%)
#  rename {cough2_drive => cough2_drrive}/222644__celesteominous__cough.wav (100%)
#  create mode 100644 cough2_drrive/240375__mariiao2__cough.wav
#  rename {cough2_drive => cough2_drrive}/245857__blukotek__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/251489__aderumoro__cough-young-lady.wav (100%)
#  rename {cough2_drive => cough2_drrive}/252212__robinhood76__05460-little-baby-bad-cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/252240__reitanna__real-cough.wav (100%)
#  create mode 100644 cough2_drrive/254467__wjoojoo__marvie-cough1.wav
#  create mode 100644 cough2_drrive/256567__sjnewton__coughing.wav
#  rename {cough2_drive => cough2_drrive}/258256__joedeshon__cough.wav (100%)
#  create mode 100644 cough2_drrive/259512__fattirewhitey__short-cough.wav
#  rename {cough2_drive => cough2_drrive}/263992__vospi__young-man-cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/266019__joedeshon__double-cough-01.wav (100%)
#  rename {cough2_drive => cough2_drrive}/272029__aldenroth2__male-cough.wav (100%)
#  create mode 100644 cough2_drrive/30830__jollysea__girl-coughing.wav
#  rename {cough2_drive => cough2_drrive}/319363__monosfera__facet-kaszle-guy-coughs-01.wav (100%)
#  create mode 100644 cough2_drrive/323532__alivvie__wheezy-coughing.wav
#  rename {cough2_drive => cough2_drrive}/324769__fatimasalas94__cough.wav (100%)
#  create mode 100644 cough2_drrive/325569__activeobjectx__coughs.wav
#  rename {cough2_drive => cough2_drrive}/325656__hourofmidnight__harsh-cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/326096__1980supra__cough-cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/331052__n-audioman__cough-02.wav (100%)
#  rename {cough2_drive => cough2_drrive}/332989__michael-kur95__coughing-01.wav (100%)
#  create mode 100644 cough2_drrive/334051__littlerainyseasons__cough.wav
#  create mode 100644 cough2_drrive/334154__oddmonolithsound__cough.wav
#  rename {cough2_drive => cough2_drrive}/336529__giddster__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/337678__grantorino551__cough.wav (100%)
#  create mode 100644 cough2_drrive/341086__cabled-mess__unprocessed-cough-rode-nt2000.wav
#  rename {cough2_drive => cough2_drrive}/342587__fattirewhitey__coughing-sfx.wav (100%)
#  rename {cough2_drive => cough2_drrive}/343880__reitanna__two-coughs.wav (100%)
#  rename {cough2_drive => cough2_drrive}/343986__reitanna__four-coughs.wav (100%)
#  rename {cough2_drive => cough2_drrive}/344632__chubbers1995__man-coughing.wav (100%)
#  rename {cough2_drive => cough2_drrive}/348134__nikomyth__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/348364__frostyfrost__cough.wav (100%)
#  create mode 100644 cough2_drrive/353669__reyhanaf__realistic-cough (1).wav
#  create mode 100644 cough2_drrive/353669__reyhanaf__realistic-cough.wav
#  create mode 100644 cough2_drrive/360460__topschool__coughing.wav
#  create mode 100644 cough2_drrive/360890__dinkdonkdork__young-male-coughing.wav
#  rename {cough2_drive => cough2_drrive}/365158__jack-freedom5712__man-coughing.wav (100%)
#  create mode 100644 cough2_drrive/365476__caitlin-100__a-person-coughing.wav
#  rename {cough2_drive => cough2_drrive}/365704__mc-minnaar__woman-coughing.wav (100%)
#  rename {cough2_drive => cough2_drrive}/366229__millonlazaruspillay__coughing.wav (100%)
#  rename {cough2_drive => cough2_drrive}/366319__et-graham__male-coughing.wav (100%)
#  rename {cough2_drive => cough2_drrive}/369295__georgisound__coughing.wav (100%)
#  rename {cough2_drive => cough2_drrive}/371360__goldkelchen__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/377953__mafaldav__paisaje-sonoro-uem-toses2.wav (100%)
#  rename {cough2_drive => cough2_drrive}/383781__deleted-user-7146007__man-coughing-sick-cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/383783__deleted-user-7146007__man-coughing-cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/385829__tylean__sharp-cough-irritant.wav (100%)
#  create mode 100644 cough2_drrive/390317__pflanigan__120716-ack.wav
#  rename {cough2_drive => cough2_drrive}/391154__dkrysta__cough-2.wav (100%)
#  rename {cough2_drive => cough2_drrive}/391284__igor1998__cough.wav (100%)
#  create mode 100644 cough2_drrive/395199__bvaudio__child-cough.wav
#  create mode 100644 cough2_drrive/399627__soundsforhim__man-coughing-1.wav
#  rename {cough2_drive => cough2_drrive}/401334__ckvoiceover__man-coughing.wav (100%)
#  rename {cough2_drive => cough2_drrive}/403881__kellyn-lyn__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/405206__drotzruhn__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/407703__170134__sick-old-man-cough.wav (100%)
#  create mode 100644 cough2_drrive/407839__bobtheross__coughing.wav
#  rename {cough2_drive => cough2_drrive}/408086__biawinter__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/408107__angelicwings__coughing.wav (100%)
#  rename {cough2_drive => cough2_drrive}/408888__puzzelz__coughing.wav (100%)
#  rename {cough2_drive => cough2_drrive}/410493__fmceretta__cough-cof-cof-cof.wav (100%)
#  rename {cough2_drive => cough2_drrive}/410964__mihirfreesound__cough-male.wav (100%)
#  rename {cough2_drive => cough2_drrive}/41386__sandyrb__db-cough-002.wav (100%)
#  rename {cough2_drive => cough2_drrive}/419437__14fsmitakovak__7-5-cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/425777__thatkellytrna__girl-cough.wav (100%)
#  create mode 100644 cough2_drrive/426271__clurky__cough-female.wav
#  create mode 100644 cough2_drrive/432193__pringlescan__voice-017.wav
#  rename {cough2_drive => cough2_drrive}/432377__sam54123__coughingfit.wav (100%)
#  create mode 100644 cough2_drrive/440692__topschool__coughing.wav
#  rename {cough2_drive => cough2_drrive}/444064__soulbaby71__coughing.wav (100%)
#  rename {cough2_drive => cough2_drrive}/444723__breviceps__short-cough-choke.wav (100%)
#  rename {cough2_drive => cough2_drrive}/445664__tilano408__31-cough-2.wav (100%)
#  rename {cough2_drive => cough2_drrive}/445730__180241virtualwindow-co-za__coughing.wav (100%)
#  rename {cough2_drive => cough2_drrive}/446491__obooth3__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/45150__delphidebrain__delphis-cough-1644-h4.wav (100%)
#  create mode 100644 cough2_drrive/45578__j-zazvurek__girl-cough.wav
#  rename {cough2_drive => cough2_drrive}/457972__fabrizio84__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/458822__lidem-soundfx__fx-toux-stereo-48khz-u87.wav (100%)
#  rename {cough2_drive => cough2_drrive}/461571__15hkvasnickovat__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/462010__15f-panska-vokulic-vaclav__coughing-human.wav (100%)
#  rename {cough2_drive => cough2_drrive}/462843__eelke__coughing.wav (100%)
#  rename {cough2_drive => cough2_drrive}/466555__danieldouch__coughs.wav (100%)
#  rename {cough2_drive => cough2_drrive}/466874__jmbland94__adult-male-coughing.wav (100%)
#  create mode 100644 cough2_drrive/470120__the-coolguy78__child-coffing.wav
#  rename {cough2_drive => cough2_drrive}/51136__rutgermuller__coughing-young-man-me.wav (100%)
#  rename {cough2_drive => cough2_drrive}/52323__stephsinger22__coughing.wav (100%)
#  rename {cough2_drive => cough2_drrive}/53663__crispy527__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/58792__syna-max__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/62291__shopp__asthma.wav (100%)
#  rename {cough2_drive => cough2_drrive}/63752__dobroide__20081118-bad-cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/82717__ifartinurgeneraldirection__cough.wav (100%)
#  create mode 100644 cough2_drrive/85292__smokeyvw__file0281-cough.wav
#  rename {cough2_drive => cough2_drrive}/87411__bowlingballout__man-cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/87412__bowlingballout__woman-cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/90727__carlcass__cough.wav (100%)
#  rename {cough2_drive => cough2_drrive}/90__plagasul__bocanada2.wav (100%)
#  rename {cough2_drive => cough2_drrive}/93031__higginsdj__wheezy-cough-24-96-stereo.wav (100%)
#  rename {cough2_drive => cough2_drrive}/96189__ifartinurgeneraldirection__cough.wav (100%)
#  create mode 100644 images/1-47714-A-16.png
#  create mode 100644 images/1-47819-A-5.png
#  create mode 100644 images/1-47819-B-5.png
#  create mode 100644 images/1-47819-C-5.png
#  create mode 100644 images/1-47923-A-28.png
#  create mode 100644 images/1-48298-A-46.png
#  create mode 100644 images/1-48413-A-38.png
#  create mode 100644 images/1-49098-A-35.png
#  create mode 100644 images/1-49409-A-8.png
#  create mode 100644 images/1-49409-B-8.png
#  create mode 100644 images/1-50060-A-10.png
#  create mode 100644 images/1-50454-A-44.png
#  create mode 100644 images/1-50455-A-44.png
#  create mode 100644 images/1-50623-A-15.png
#  create mode 100644 images/1-50625-A-17.png
#  create mode 100644 images/1-50661-A-44.png
#  create mode 100644 images/1-50688-A-17.png
#  create mode 100644 images/1-51035-A-16.png
#  create mode 100644 images/1-51036-A-16.png
#  create mode 100644 images/1-51037-A-16.png
#  create mode 100644 images/1-51147-A-25.png
#  create mode 100644 images/1-51170-A-18.png
#  create mode 100644 images/1-51433-A-17.png
#  create mode 100644 images/1-51436-A-17.png
#  create mode 100644 images/1-51805-A-33.png
#  create mode 100644 images/1-51805-B-33.png
#  create mode 100644 images/1-51805-C-33.png
#  create mode 100644 images/1-51805-D-33.png
#  create mode 100644 images/1-51805-E-33.png
#  create mode 100644 images/1-51805-F-33.png
#  create mode 100644 images/1-51805-G-33.png
#  create mode 100644 images/1-51805-H-33.png
#  create mode 100644 images/1-52266-A-24.png
#  create mode 100644 images/1-52290-A-30.png
#  create mode 100644 images/1-52323-A-24.png
#  create mode 100644 images/1-53444-A-28.png
#  create mode 100644 images/1-53467-A-47.png
#  create mode 100644 images/1-53501-A-32.png
#  create mode 100644 images/1-53663-A-24.png
#  create mode 100644 images/1-53670-A-18.png
#  create mode 100644 images/1-54065-A-45.png
#  create mode 100644 images/1-54065-B-45.png
#  create mode 100644 images/1-54084-A-42.png
#  create mode 100644 images/1-54505-A-21.png
#  create mode 100644 images/1-54747-A-46.png
#  create mode 100644 images/1-54752-A-18.png
#  create mode 100644 images/1-54918-A-14.png
#  create mode 100644 images/1-54918-B-14.png
#  create mode 100644 images/1-54958-A-10.png
#  create mode 100644 images/1-56233-A-9.png
#  create mode 100644 images/1-56234-A-9.png
#  create mode 100644 images/1-56269-A-18.png
#  create mode 100644 images/1-56270-A-29.png
#  create mode 100644 images/1-56311-A-10.png
#  create mode 100644 images/1-56380-A-5.png
#  create mode 100644 images/1-56380-B-5.png
#  create mode 100644 images/1-56907-A-46.png
#  create mode 100644 images/1-57163-A-38.png
#  create mode 100644 images/1-57316-A-13.png
#  create mode 100644 images/1-57318-A-13.png
#  create mode 100644 images/1-57795-A-8.png
#  create mode 100644 images/1-58277-A-3.png
#  create mode 100644 images/1-58792-A-24.png
#  create mode 100644 images/1-58846-A-34.png
#  create mode 100644 images/1-58923-A-27.png
#  create mode 100644 images/1-58923-B-27.png
#  create mode 100644 images/1-59102-A-13.png
#  create mode 100644 images/1-59324-A-21.png
#  create mode 100644 images/1-59513-A-0.png
#  create mode 100644 images/1-5996-A-6.png
#  create mode 100644 images/1-60460-A-36.png
#  create mode 100644 images/1-60676-A-34.png
#  create mode 100644 images/1-60997-A-20.png
#  create mode 100644 images/1-60997-B-20.png
#  create mode 100644 images/1-61212-A-32.png
#  create mode 100644 images/1-61221-A-17.png
#  create mode 100644 images/1-61252-A-11.png
#  create mode 100644 images/1-61261-A-44.png
#  create mode 100644 images/1-61534-A-27.png
#  create mode 100644 images/1-62509-A-45.png
#  create mode 100644 images/1-62565-A-44.png
#  create mode 100644 images/1-62594-A-32.png
#  create mode 100644 images/1-62849-A-38.png
#  create mode 100644 images/1-62850-A-38.png
#  create mode 100644 images/1-63679-A-24.png
#  create mode 100644 images/1-63871-A-10.png
#  create mode 100644 images/1-64398-A-41.png
#  create mode 100644 images/1-64398-B-41.png
#  create mode 100644 images/1-64473-A-45.png
#  create mode 100644 images/1-65483-A-13.png
#  create mode 100644 images/1-67033-A-37.png
#  create mode 100644 images/1-67152-A-17.png
#  create mode 100644 images/1-67230-A-29.png
#  create mode 100644 images/1-67432-A-27.png
#  create mode 100644 images/1-68628-A-27.png
#  create mode 100644 images/1-68670-A-34.png
#  create mode 100644 images/1-68734-A-34.png
#  create mode 100644 images/1-69165-A-34.png
#  create mode 100644 images/1-69422-A-3.png
#  create mode 100644 images/1-69641-A-3.png
# fatal: remote origin already exists.
# To https://github.com/CharlesNJohn/Cough.git
#    785d162..9015ea5  master -> master

# %%
# !git remote -v
# Out:
# origin	https://github.com/CharlesNJohn/Cough.git (fetch)
# origin	https://github.com/CharlesNJohn/Cough.git (push)

# %%
# !git push origin master
# Out:
# Everything up-to-date

# %%
# !git commit -m "updated"
# Out:
# On branch master
# nothing to commit, working tree clean

# %%
for filename in os.listdir(audio_dir):
    for i in range(0, 140):

            x, fs = load_wave_data(audio_dir, meta_data.loc[i,"filename"])
            melsp = calculate_melsp(x)
            librosa.display.specshow(melsp, sr=fs)
            
            label_sm='SM'+str(i)+'-'+meta_data.loc[i,"filename"]
            label_sm_renamed=os.path.splitext(label_sm)[0]
            plt.axis('off')
            plt.savefig('images/cough2_drive/'+label_sm_renamed+'.png',bbox_inches=None,pad_inches=0)
            #plt.show()
            #show_melsp(melsp, fs)
            
            
            
            '''fig, ax = plt.subplots( nrows=1, ncols=1 ) # create figure & 1 axis
            ax.plot([0,1,2], [10,20,3])
            fig.savefig('o.png') # save the figure to file
            plt.close(fig) # close the figure'''
            
            x_wn = add_white_noise(x)
            melsp = calculate_melsp(x_wn)
            librosa.display.specshow(melsp, sr=fs)
            
            #show_melsp(melsp, fs)
            label_wn='WN'+str(i)+'-'+meta_data.loc[i,"filename"]
            label_wn_renamed=os.path.splitext(label_wn)[0]
            plt.savefig('images/cough2_drive/'+label_wn_renamed+'.png',bbox_inches=None,pad_inches=0)
            #plt.show()

            
            x_ss = shift_sound(x)
            melsp = calculate_melsp(x_ss)
            librosa.display.specshow(melsp, sr=fs)
            
            label_ss='SS'+str(i)+'-'+meta_data.loc[i,"filename"]
            label_ss_renamed=os.path.splitext(label_ss)[0]
            plt.savefig('images/cough2_drive/'+label_ss_renamed+'.png',bbox_inches=None,pad_inches=0)
            #plt.show()

            x_st = stretch_sound(x)
            melsp = calculate_melsp(x_st)
            librosa.display.specshow(melsp, sr=fs)
            
            label_st='ST'+str(i)+'-'+meta_data.loc[i,"filename"]
            label_st_renamed=os.path.splitext(label_st)[0]
            plt.savefig('images/cough2_drive/'+label_st_renamed+'.png',bbox_inches=None,pad_inches=0)
            #plt.show()
            
            print(i)
# Out:
# ---------------------------------------------------------------------------
# NoBackendError                            Traceback (most recent call last)
# <ipython-input-53-a9b4de63bd1c> in <module>()
#       2     for i in range(0, 140):
#       3
# ----> 4             x, fs = load_wave_data(audio_dir, meta_data.loc[i,"filename"])
#       5             melsp = calculate_melsp(x)
#       6             librosa.display.specshow(melsp, sr=fs)
#
# <ipython-input-39-7cf83c3ce66b> in load_wave_data(audio_dir, file_name)
#       2 def load_wave_data(audio_dir, file_name):
#       3     file_path = os.path.join(audio_dir, file_name)
# ----> 4     x, fs = librosa.load(file_path, sr=44100)
#       5     return x,fs
#
# C:\Users\Charles\Anaconda2\lib\site-packages\librosa\core\audio.pyc in load(path, sr, mono, offset, duration, dtype, res_type)
#     117
#     118     y = []
# --> 119     with audioread.audio_open(os.path.realpath(path)) as input_file:
#     120         sr_native = input_file.samplerate
#     121         n_channels = input_file.channels
#
# C:\Users\Charles\Anaconda2\lib\site-packages\audioread\__init__.pyc in audio_open(path)
#     114
#     115     # All backends failed!
# --> 116     raise NoBackendError()
#
# NoBackendError:

# %%
# !ls
# Out:
# Cough-Copy1.ipynb
# Cough.ipynb
# CoughRedundant.ipynb
# Untitled.ipynb
# audio_cough only
# cough.xlsx
# cough1_drive
# cough2_drive.csv
# cough2_drrive
# cough_downloaded
# cough_labels.csv
# cough_only
# images
# train
# train_labels.csv
# train_labels_2000.csv
# train_labels_backup.csv

# %%
# !pwd
